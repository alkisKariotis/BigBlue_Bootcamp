# %% [markdown]
# # INTRO TO PANDAS

# %% [markdown]
# # 1.Open the csv file using pandas. Check characteristics of the dataset. What is the shape of the dataset, what are the statistics of the columns, are there any NaNs?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vgsales.csv')

# %%
df
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#        Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df.shape
# Out:
# (16598, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16598 non-null  object
#  1   Platform      16598 non-null  object
#  2   Year          16327 non-null  float64
#  3   Genre         16598 non-null  int64
#  4   Publisher     16540 non-null  object
#  5   NA_Sales      16598 non-null  float64
#  6   EU_Sales      16598 non-null  float64
#  7   JP_Sales      16598 non-null  float64
#  8   Other_Sales   16598 non-null  float64
#  9   Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#                Year         Genre      NA_Sales      EU_Sales      JP_Sales  \
# count  16327.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    2006.406443      6.260333      0.264667      0.146652      0.077782
# std        5.828981      3.421823      0.816683      0.505351      0.309291
# min     1980.000000      1.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      3.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      7.000000      0.080000      0.020000      0.000000
# 75%     2010.000000      9.000000      0.240000      0.110000      0.040000
# max     2020.000000     12.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
#to see in which columns are the NaNs located
df.isna().sum()
# Out:
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# # 2.Clean the dataset (if you find any NaNs)

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16291 non-null  object
#  1   Platform      16291 non-null  object
#  2   Year          16291 non-null  float64
#  3   Genre         16291 non-null  int64
#  4   Publisher     16291 non-null  object
#  5   NA_Sales      16291 non-null  float64
#  6   EU_Sales      16291 non-null  float64
#  7   JP_Sales      16291 non-null  float64
#  8   Other_Sales   16291 non-null  float64
#  9   Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# # 3.Which game has the highest global sales? What is its platform?

# %%
df.iloc[df['Global_Sales'].idxmax()]
# Out:
# Name            Wii Sports
# Platform               Wii
# Year                  2006
# Genre                    1
# Publisher         Nintendo
# NA_Sales             41.49
# EU_Sales             29.02
# JP_Sales              3.77
# Other_Sales           8.46
# Global_Sales         82.74
# Name: 0, dtype: object

# %%
df
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#        Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# # 4.Which are the platforms in the dataset?

# %%
df['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# # 5.Which are the top ten selling games for PS4 (Global sales)? Is this the same for Europe and Japan sales combined?

# %%
#top 10 based on Global_Sales
df[df['Platform']=='PS4'].sort_values('Global_Sales',ascending=False).head(10)
# Out:
#                                Name Platform    Year  Genre  \
# 33        Call of Duty: Black Ops 3      PS4  2015.0      7
# 44               Grand Theft Auto V      PS4  2014.0      9
# 77                          FIFA 16      PS4  2015.0      1
# 92     Star Wars Battlefront (2015)      PS4  2015.0      7
# 93   Call of Duty: Advanced Warfare      PS4  2014.0      7
# 109                       Fallout 4      PS4  2015.0      4
# 124                         FIFA 15      PS4  2014.0      1
# 154                         Destiny      PS4  2014.0      7
# 221                         FIFA 17      PS4  2016.0      1
# 236                  The Last of Us      PS4  2014.0      9
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 33                    Activision      5.77      5.81      0.35         2.31
# 44          Take-Two Interactive      3.80      5.81      0.36         2.02
# ...

# %% [markdown]
# # 6.How many games were released for XOne in 2016? Which was the top selling in Europe?

# %%
df['Platform'][(df['Platform']=='XOne') & (df['Year']==2016)].count()
# Out:
# 54

# %%
#df.iloc[(df['Platform']=='XOne') & (df['Year']==2016).idxmax()]
#df.iloc[df['Global_Sales'].idxmax()]
df[(df['Platform']=='XOne') & (df['Year']==2016)].iloc[df['Global_Sales'].idxmax()]
# Out:
# Name            Tom Clancy's The Division
# Platform                             XOne
# Year                                 2016
# Genre                                   7
# Publisher                         Ubisoft
# NA_Sales                              1.2
# EU_Sales                             0.62
# JP_Sales                                0
# Other_Sales                          0.18
# Global_Sales                         2.01
# Name: 845, dtype: object

# %%
df[(df['Platform']=='XOne') & (df['Year']==2016)].sort_values('Global_Sales',ascending=False).head(1)
# Out:
#                           Name Platform    Year  Genre Publisher  NA_Sales  \
# 845  Tom Clancy's The Division     XOne  2016.0      7   Ubisoft       1.2
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 845      0.62       0.0         0.18          2.01

# %% [markdown]
# # 7.Replace where XOne with ‘X Box One’

# %%
df2 = df.copy()
df2['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df2.replace('XOne','X Box One',inplace=True)
df2['Platform'].unique()
#df2.tail(40)
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'X Box One',
#        'GC', 'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# # 8.How many PC games have higher sales than 3 million global sales?

# %%
df2['Global_Sales'][df2['Platform']=='PC'][df2['Global_Sales']>3].count()
# Out:
# 12

# %% [markdown]
# # 9.In which year the most games were released?

# %%
x=df2.groupby('Year').count().sort_values('Name')#.tail(1).reset_index()#['Year'][0]
#.index[0]
x
# Out:
#         Name  Platform  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Year
# 2020.0     1         1      1          1         1         1         1
# 2017.0     3         3      3          3         3         3         3
# 1980.0     9         9      9          9         9         9         9
# 1984.0    14        14     14         14        14        14        14
# 1985.0    14        14     14         14        14        14        14
# 1988.0    15        15     15         15        15        15        15
# 1987.0    16        16     16         16        16        16        16
# 1990.0    16        16     16         16        16        16        16
# 1983.0    17        17     17         17        17        17        17
# 1989.0    17        17     17         17        17        17        17
# 1986.0    21        21     21         21        21        21        21
# 1982.0    36        36     36         36        36        36        36
# ...

# %% [markdown]
# # 10.Which platform had the most releases that year?

# %%
#df2['Platform'][df2['Year']==x].count().iloc[]
#df2['Platform'][df2['Year']==x].count()
df2[df2['Year']==x].groupby('Platform').count().sort_values('Name').tail(1).index[0]
# Out:
# 'DS'

# %% [markdown]
# # 11.Which are the top 5 selling platforms (games global sales) of all time? Plot your results in a graph

# %%
df2.groupby('Platform').sum().sort_values('Global_Sales',ascending=False).head(5)
# Out:
#                Year  Genre  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Platform
# PS2       4263750.0  12738    572.92    332.63    137.54       190.47
# X360      2480191.0   7651    594.33    278.00     12.30        84.67
# PS3       2622109.0   8254    388.90    340.47     79.21       140.81
# Wii       2591562.0   7480    497.37    264.35     68.28        79.20
# DS        4279469.0  14283    388.53    194.05    175.02        60.29
#
#           Global_Sales
# Platform
# PS2            1233.46
# X360            969.60
# PS3             949.35
# Wii             909.81
# DS              818.91

# %%
df2.groupby('Platform').sum().sort_values('Global_Sales',ascending=False).head(5)['Global_Sales']
# Out:
# Platform
# PS2     1233.46
# X360     969.60
# PS3      949.35
# Wii      909.81
# DS       818.91
# Name: Global_Sales, dtype: float64

# %%
df2.groupby('Platform').sum().sort_values('Global_Sales',ascending=False).head(5)['Global_Sales'].plot.bar()

# %% [markdown]
# # 12.Which are the top three publishers in EU game sales? Use a pie plot to show their contribution. How is it compared with their global sales? Use plots to show your results.

# %%
df2.groupby('Publisher').sum().sort_values('EU_Sales',ascending=False)['EU_Sales'].head(3).plot(kind='pie', y='EU_Sales', autopct='%1.0f%%')

# %%
df2.groupby('Publisher').sum().sort_values('EU_Sales',ascending=False)[['EU_Sales','Global_Sales']].head(3).plot.bar()

# %% [markdown]
# # 13.Use map and the following dictionary to replace the genres.

# %%
dic = {1:'Sports',2:'Platform',3:'Racing',4:'Role-Playing',5:'Puzzle',6:'Misc',
       7:'Shooter',8:'Simulation',9:'Action',10:'Fighting',11:'Adventure',12:'Strategy'}

def replacement_dic(x):
    for key in dic.keys():
        if key==x:
            return dic[key]

df2['Genre']=list(map(replacement_dic,df2['Genre']))
df2
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# # 14.Which action game has the highest global sales?

# %%
df2[df2['Genre']=='Action'].groupby('Name').sum().sort_values('Global_Sales',ascending=False)['Global_Sales'].index[0]
# Out:
# 'Grand Theft Auto V'

# %%
#df2

# %% [markdown]
# # 15.Which are the top 5 most mentioned genres of all time? Is this different in 2014, 2015, 2016?

# %%
df2.groupby('Genre').count().sort_values('Name',ascending=False).head(5).index
# Out:
# Index(['Action', 'Sports', 'Misc', 'Role-Playing', 'Shooter'], dtype='object', name='Genre')

# %%
df2[(df2['Year']==2014)|(df2['Year']==2015)|(df2['Year']==2016)].groupby(['Genre','Year']).count().sort_values('Name',ascending=False)
# Out:
#                      Name  Platform  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Genre        Year
# Action       2015.0   255       255        255       255       255       255
#              2014.0   186       186        186       186       186       186
#              2016.0   118       118        118       118       118       118
# Role-Playing 2014.0    90        90         90        90        90        90
#              2015.0    78        78         78        78        78        78
# Adventure    2014.0    75        75         75        75        75        75
# Sports       2015.0    62        62         62        62        62        62
#              2014.0    55        55         55        55        55        55
# Adventure    2015.0    54        54         54        54        54        54
# Shooter      2014.0    47        47         47        47        47        47
# Misc         2014.0    41        41         41        41        41        41
# ...
